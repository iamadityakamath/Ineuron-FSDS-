# %% [markdown]
# # String Basics (May 15)

# %% [markdown]
# ##### By:
# ##### Aditya Kamath
# ##### Date of Submission: 16/07/22

# %% [markdown]
# s= "this is My First Python programming class and i am learNING python string and its function."
# 1. Try to extract data from index one to index 300 with a jump of 3
# 2. Try to reverse a string without using reverse function
# 3. Try to split a string after conversion of entire string in uppercase
# 4. try to convert the whole string into lower case
# 5. Try to capitalize the whole string
# 6. Write a diference between isalnum()and isalpha()
# 7. Try to give an example of expand tab
# 8. Give an example of strip,lstrip and rstrip
# 9. Replace a string charecter by another charector by taking your own example
# 10. Try to give a defination of string center function with and exmple
# 11. Write your own definition of compiler and interpretor without copy paste form internet in your own words.
# 12. Python is a interpreted of compiled language giveaclear ans with your understanding
# 13. Try to write a usecase of python with your understanding

# %%
# 1. Try to extract data from index one to index 300 with a jump of 3
s= "this is My First Python programming class and i am learNING python string and its function."
print(s[1:300:3])
# Out:
# h   r tnrrmglsnimeNGyosi dtfco

# %%
# 2. Try to reverse a string without using reverse function 
s = "Hello Aditya"
print(s[::-1])
# Out:
# aytidA olleH

# %%
# 3. Try to split a string after conversion of entire string in uppercase
s = "Hello Aditya"
s = s.upper()
s = s.split(" ")
s
# Out:
# ['HELLO', 'ADITYA']

# %%
# 4. try to convert the whole string into lower case
s = "Hello Aditya"
s = s.lower()
s
# Out:
# 'hello aditya'

# %%
# 5. Try to capitalize the whole string
s = "Hello Aditya"
s = s.capitalize()
s
# Out:
# 'Hello aditya'

# %%
# 6. Write a diference between isalnum()and isalpha()

# isalnum: It represents alpha numeric charachter. Thus if a string has alphabets or numerical charachter, it gives True output.
# isalpha: It only represents alpha charachter and if any other charachter present in string, will return false.

# %%
# 7. Try to give an example of expand tab
s = "hhe\tgge\thi"
s.expandtabs()
# here we can see that it only changes to 1 tab space where there is \t in the string.
# Out:
# 'hhe     gge     hi'

# %%
# 8. Give an example of strip,lstrip and rstrip
s = "...hello Aditya###"
print("Normal strip: ",s.strip(".#"))
print("Left strip: ",s.lstrip(".#"))
print("Right strip: ",s.rstrip(".#"))
# Out:
# Normal strip:  hello Aditya
# Left strip:  hello Aditya###
# Right strip:  ...hello Aditya

# %%
# 9. Replace a string charecter by another charector by taking your own example
s = "Hello Aditya"
s.replace("l","a")
# Out:
# 'Heaao Aditya'

# %%
# 10. Try to give a defination of string center function with and exmple

# Center: It uses padding of given character to align the text to be displayed in centre of the given digit.
s = "Hello Aditya"
s.center(20)
# Out:
# '    Hello Aditya    '

# %%
#  11. Write your own definition of compiler and interpretor without copy paste form internet in your own words.
"""
Compiler: It is used to process our code such that it is readable by the machine. 

Interpretor:  It is basically the syntax which we write the code in. A certain set of rules we give 
              which should be followed such as both brackets should be complete while trying to print,etc."""

# %%
# 12. Python is a interpreted or compiled language give a clear ans with your understanding

"""
 Python is an interpreted language. We define a set of rules before it can be read by a machine. Machine reads the 
 input in bytes. Python just has rules to be followed. Compiler takes care of the rest while executing.
"""

# %%
# 13. Try to write a usecase of python with your understanding 
"""
Python is a very easy language with vast amount of libraries. Due to its support, it can be used in the field of AI and ML.
Apart from there, there are web frameworks such as Socket, Django, Streamlit which can be used to develope Web applications.
"""
